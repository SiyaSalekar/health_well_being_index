# %%
import pandas as pd

file_path = 'C:/Users/SIYA/Downloads/DAV_CA_data/life_expectancy_data.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
data.describe()
# there are missing values since count of columns is different should be 2938 for all 
# also from min max values we see data needs to be scaled
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
#check data types of cols
column_data_types = data.dtypes
print(column_data_types)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
# Create a new binary column based on the "Status" column
data['Country_Status'] = data['Status'].apply(lambda x: 1 if x == 'Developed' else 0)

# Drop the original "Status" column 
data.drop('Status', axis=1, inplace=True)
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Country_Status'],
#       dtype='object')

# %%
#check missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Country                              0
# Year                                 0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Country_Status                       0
# dtype: int64

# %%
#focusing on only european countries
# List of European countries
european_countries = [
    "Albania", "Armenia", "Austria", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina", "Bulgaria",
    "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Greece",
    "Hungary", "Iceland", "Ireland", "Italy", "Kazakhstan", "Kosovo", "Latvia", "Lithuania", "Luxembourg", "Malta",
    "Moldova", "Monaco", "Montenegro", "Netherlands", "North Macedonia", "Norway", "Poland", "Portugal", "Romania",
    "Russia", "San Marino", "Serbia", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "Ukraine",
    "United Kingdom", "Vatican City"
]

# Filter out European countries
data = data[data['Country'].isin(european_countries)]

# %%
# cleaning data

# Check if the country has data for each year from 2000 to 2015

countries_to_delete = []  
for country in data['Country'].unique():
    years = data[data['Country'] == country]['Year'].unique()
    if set(range(2000, 2016)).difference(years):
        print(f"{country} is missing data for the following years:", end=" ")
        missing_years = set(range(2000, 2016)).difference(years)
        print(missing_years)
        countries_to_delete.append(country)
# Out:
# Monaco is missing data for the following years: {2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2015}
# San Marino is missing data for the following years: {2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2015}

# %%
#delete above country rows since they have data only for the year 2013
data = data[~data['Country'].isin(countries_to_delete)]

# %%
#POPULATION MISSING VALUES

#read population data and fill missing values for current data
file_path = 'C:/Users/SIYA/Downloads/EDU_DEM_03052024202813726.csv'
population_data = pd.read_csv(file_path)

# %%
# Function to fill missing population values
def fill_missing_population(row):
    year = row['Year']
    country = row['Country']
    population_value = row['Population']
    if pd.isnull(population_value):  # Check if the population value is missing
        matching_population = population_data[(population_data['Country'] == country) & (population_data['YEAR'] == year)]['Value'].values
        if len(matching_population) > 0:
            return matching_population[0]
    return population_value  # Return the original value if it's not missing

# Apply the function to fill missing values in the Population column
data['Population'] = data.apply(fill_missing_population, axis=1)

print(data)
# Out:
#       Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 16    Albania  2015              77.8             74.0              0
# 17    Albania  2014              77.5              8.0              0
# 18    Albania  2013              77.2             84.0              0
# 19    Albania  2012              76.9             86.0              0
# 20    Albania  2011              76.6             88.0              0
# ...       ...   ...               ...              ...            ...
# 2741  Ukraine  2004              67.4            267.0              5
# 2742  Ukraine  2003              67.6            256.0              6
# 2743  Ukraine  2002              67.6            256.0              6
# 2744  Ukraine  2001              67.7            253.0              6
# 2745  Ukraine  2000              67.5            257.0              6
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 16       4.60              364.975229         99.0         0   58.0  ...
# 17       4.51              428.749067         98.0         0   57.2  ...
# 18       4.76              430.876979         99.0         0   56.5  ...
# 19       5.14              412.443356         99.0         9   55.8  ...
# 20       5.37              437.062100         99.0        28   55.1  ...
# ...       ...                     ...          ...       ...    ...  ...
# 2741     6.79              180.353786         98.0       146   56.1  ...
# 2742     5.92               21.223864         77.0       411   55.7  ...
# 2743     4.89              115.738974         48.0      7587   55.4  ...
# 2744     4.31                8.897421          7.0     16970   55.1  ...
# 2745     4.49                7.883791          4.0       817   54.8  ...
#
#       Total expenditure  Diphtheria    HIV/AIDS          GDP  Population  \
# 16                 6.00         99.0        0.1  3954.227830     28873.0
# 17                 5.88         98.0        0.1  4575.763787    288914.0
# 18                 5.66         99.0        0.1  4414.723140    289592.0
# 19                 5.59         99.0        0.1  4247.614380      2941.0
# 20                 5.71         99.0        0.1  4437.178680    295195.0
# ...                 ...          ...        ...          ...         ...
# 2741               6.61         99.0        1.0  1367.352433    474516.0
# 2742               6.93         97.0        0.9   148.522488   4781295.0
# 2743               6.25         99.0        0.9   879.475486     48225.0
# 2744               5.66         99.0        0.8    78.738243  48683865.0
# 2745               5.59         99.0        0.7   635.789635  49175848.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 16                      1.2                  1.3
# 17                      1.2                  1.3
# 18                      1.3                  1.4
# 19                      1.3                  1.4
# 20                      1.4                  1.5
# ...                     ...                  ...
# 2741                    2.7                  2.8
# 2742                    2.8                  2.9
# 2743                    2.9                  3.0
# 2744                    2.9                  3.0
# 2745                    3.0                  3.1
#
#       Income composition of resources  Schooling  Country_Status
# 16                              0.762       14.2               0
# 17                              0.761       14.2               0
# 18                              0.759       14.2               0
# 19                              0.752       14.2               0
# 20                              0.738       13.3               0
# ...                               ...        ...             ...
# 2741                            0.700       14.6               0
# 2742                            0.691       14.3               0
# 2743                            0.683       13.9               0
# 2744                            0.673       13.2               0
# 2745                            0.669       13.3               0
#
# [656 rows x 22 columns]

# %%
# for countries not in population data fill using dict obtained from - https://www.macrotrends.net/global-metrics/countries/SGP/<country-name>/population 
# replace <country-name> with country name

# Define a dictionary to map countries to their population data
population_dict = {
    'Czechia': {
        2009: 10421510,
        2008: 10378583,
        2007: 10337829,
        2006: 10304815,
        2004: 10260999,
        2003: 10248038,
        2002: 10238170,
        2001: 10230276
    },
    'Slovakia': {
        2015: 5424444,
        2014: 5419569,
        2013: 5414739,
        2012: 5409283,
        2011: 5402680,
        2010: 5396424,
        2009: 5388926,
        2008: 5381636,
        2007: 5378382,
        2006: 5377235,
        2005: 5376242,
        2004: 5374931,
        2003: 5374376,
        2002: 5375206,
        2001: 5376456,
        2000: 5376690
    }
}

# Fill missing population values based on the dictionary
for index, row in data.iterrows():
    if pd.isnull(row['Population']):
        country = row['Country']
        year = row['Year']
        if country in population_dict and year in population_dict[country]:
            data.at[index, 'Population'] = population_dict[country][year]

# %%
#check missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Country                              0
# Year                                 0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                             40
# percentage expenditure               0
# Hepatitis B                        176
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                6
# Total expenditure                   40
# Diphtheria                           6
#  HIV/AIDS                            0
# GDP                                 32
# Population                           0
#  thinness  1-19 years                0
#  thinness 5-9 years                  0
# Income composition of resources     16
# Schooling                           16
# Country_Status                       0
# dtype: int64

# %%
#Hepatitis B MISSING VALUES

# countries with all missing Hepatitis B values
countries_with_missing_hep_b = set()

def fill_missing_hepatitis_b(row):
    global countries_with_missing_hep_b
    country = row['Country']
    hep_b_values = data[data['Country'] == country]['Hepatitis B']
    if hep_b_values.isnull().all() and country not in countries_with_missing_hep_b:
        print(f"All Hepatitis B values missing for {country}")
        countries_with_missing_hep_b.add(country)
    elif not hep_b_values.isnull().all():
        country_mean = hep_b_values.mean()
        row['Hepatitis B'] = country_mean
    return row

#fill missing values in the Hepatitis B column
data = data.apply(fill_missing_hepatitis_b, axis=1)
# Out:
# All Hepatitis B values missing for Denmark
# All Hepatitis B values missing for Finland
# All Hepatitis B values missing for Hungary
# All Hepatitis B values missing for Iceland
# All Hepatitis B values missing for Norway
# All Hepatitis B values missing for Slovenia
# All Hepatitis B values missing for Switzerland

# %%
#for countries with missing values for all years for hepatits B fill with avg
#found from - https://med.stanford.edu/liver/research/global-vaccination-coverage.html 

# Manually set Hepatitis B values for specific countries
hepatitis_b_values = {
    'Finland': 2,
    'Denmark': 2,
    'Hungary': 2,
    'Iceland': 2,
    'Norway': 96,
    'Slovenia': 2,
    'Switzerland': 72
}
data.loc[data['Country'].isin(hepatitis_b_values.keys()), 'Hepatitis B'] = data['Country'].map(hepatitis_b_values)

# %%
def fill_missing_alcohol(row):
    country = row['Country']
    alcohol_values = data[(data['Country'] == country) & data['Alcohol'].notna()]['Alcohol']
    if alcohol_values.any():  # Check if any non-missing values exist for the country
        country_mean = alcohol_values.mean()
        row['Alcohol'] = row['Alcohol'] if not pd.isna(row['Alcohol']) else country_mean
    return row

# Apply the function to fill missing values in the Alcohol column
data = data.apply(fill_missing_alcohol, axis=1)

# Check missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)

# Check if conversion was successful
print(data['Alcohol'].dtype)
# Out:
# Missing Values:
#  Country                             0
# Year                                0
# Life expectancy                     0
# Adult Mortality                     0
# infant deaths                       0
# Alcohol                             0
# percentage expenditure              0
# Hepatitis B                         0
# Measles                             0
#  BMI                                0
# under-five deaths                   0
# Polio                               6
# Total expenditure                  40
# Diphtheria                          6
#  HIV/AIDS                           0
# GDP                                32
# Population                          0
#  thinness  1-19 years               0
#  thinness 5-9 years                 0
# Income composition of resources    16
# Schooling                          16
# Country_Status                      0
# dtype: int64
# float64

# %%
# replace missing values for Total expenditure, Polio, GDP, Diphtheria, Income composition of resources, Schooling with mean of each column since very small amount of data missing (<35 rows)      

columns_to_fill = ['Total expenditure', 'Polio', 'GDP', 'Diphtheria ', 'Income composition of resources', 'Schooling']

# Iterate through each column and fill missing values with column mean
for col in columns_to_fill:
    data[col].fillna(data[col].mean(), inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Define columns to scale
columns_to_scale = [col for col in data.columns if col not in ['Country', 'Year', 'Country_Status',' HIV/AIDS']]

# Fit and transform each selected column
for col in columns_to_scale:
    scaler.fit(data[[col]])
    data[col] = scaler.transform(data[col].values.reshape(-1, 1))
# Out:
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
data.head()
# Out:
#     Country  Year  Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# 16  Albania  2015          0.553785         0.248299            0.0  0.256999
# 17  Albania  2014          0.541833         0.023810            0.0  0.251960
# 18  Albania  2013          0.529880         0.282313            0.0  0.265957
# 19  Albania  2012          0.517928         0.289116            0.0  0.287234
# 20  Albania  2011          0.505976         0.295918            0.0  0.300112
#
#     percentage expenditure  Hepatitis B  Measles       BMI   ...  \
# 16                0.018736     0.994175  0.000000  0.820155  ...
# 17                0.022010     0.994175  0.000000  0.807752  ...
# 18                0.022119     0.994175  0.000000  0.796899  ...
# 19                0.021173     0.994175  0.000211  0.786047  ...
# 20                0.022437     0.994175  0.000655  0.775194  ...
#
#     Total expenditure  Diphtheria    HIV/AIDS       GDP  Population  \
# 16           0.450782     1.000000        0.1  0.033081    0.000349
# 17           0.439742     0.989362        0.1  0.038297    0.003500
# 18           0.419503     1.000000        0.1  0.036946    0.003508
# 19           0.413063     1.000000        0.1  0.035543    0.000035
# 20           0.424103     1.000000        0.1  0.037134    0.003576
#
#      thinness  1-19 years   thinness 5-9 years  \
# 16                   0.18                 0.22
# 17                   0.18                 0.22
# 18                   0.20                 0.24
# 19                   0.20                 0.24
# 20                   0.22                 0.26
#
#     Income composition of resources  Schooling  Country_Status
# 16                         0.803797   0.739583               0
# 17                         0.802743   0.739583               0
# 18                         0.800633   0.739583               0
# 19                         0.793249   0.739583               0
# 20                         0.778481   0.692708               0
#
# [5 rows x 22 columns]

# %%
# For multivariate analysis lets assume dependent variable - Life expectancy
# independant variables - all remaining variables

print(data.columns)
# adjusting column names
data.columns = data.columns.str.strip().str.replace(' ', '_').str.replace('-', '_')
# Display the modified column names
print("")
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Country_Status'],
#       dtype='object')
#
# Index(['Country', 'Year', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling',
#        'Country_Status'],
#       dtype='object')

# %%
#OUTLIERS

with_outliers = data.copy()
with_outliers.drop('Year', axis=1, inplace=True)

def show_boxplot(df):
    plt.rcParams['figure.figsize'] = [14, 6]
    sns.boxplot(data=df, orient='v')
    plt.title("Outliers Distribution", fontsize=16)
    plt.ylabel("Range", fontweight='bold')
    plt.xlabel("Attributes", fontweight='bold')

show_boxplot(with_outliers)
# Out:
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
# # import seaborn as sb
# # import matplotlib.pyplot as plt

# data = data.drop(columns=['Year'])

# def show_boxplot(df):
#     plt.rcParams['figure.figsize'] = [14, 6]
#     sb.boxplot(data=df, orient='v')
#     plt.title("Outliers Distribution", fontsize=16)
#     plt.ylabel("Range", fontweight='bold')
#     plt.xlabel("Attributes", fontweight='bold')
#     plt.show()

# show_boxplot(data)
# def remove_outliers(data):
#     df = data.copy()
#     columns_to_exclude = ['Country', 'Year']
#     for col in df.columns:
#         if col not in columns_to_exclude:
#             Q1 = df[col].quantile(0.25)
#             Q3 = df[col].quantile(0.75)
#             IQR = Q3 - Q1
#             lower_bound = Q1 - 1.5 * IQR
#             upper_bound = Q3 + 1.5 * IQR
#             df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
#     return df

# # Assuming you have your data loaded into 'data' DataFrame
# # Store the 'HIV/AIDS' column separately
# hiv_aids_column = data['HIV/AIDS']

# # Drop 'Country', 'Year', and 'HIV/AIDS' columns for outlier removal
# data = remove_outliers(data.drop(columns=['Country', 'Year', 'HIV/AIDS']))

# # Now concatenate the 'HIV/AIDS' column back to the DataFrame
# data['HIV/AIDS'] = hiv_aids_column

# # Now, let's visualize the boxplot before and after removing outliers
# show_boxplot(data)
# data.shape

# %%
#Life Expectancy Outliers 
# Using Inter-Quartile Method
Q1 = data['Life_expectancy'].quantile(0.25)
Q3 = data['Life_expectancy'].quantile(0.75)
# Calculate IQR
IQR = Q3 - Q1
# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Identify outliers
outliers = data[(data['Life_expectancy'] < lower_bound) | (data['Life_expectancy'] > upper_bound)]
#printing outliers to see if not all data(for all years) for a country is deleted
print(outliers)
# Remove outliers
data = data[(data['Life_expectancy'] >= lower_bound) & (data['Life_expectancy'] <= upper_bound)]
# Out:
#          Country  Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# 1361  Kazakhstan  2000              0.0         0.989796       0.204545
#
#        Alcohol  percentage_expenditure  Hepatitis_B   Measles      BMI  ...  \
# 1361  0.335386                0.005777     0.987055  0.005734  0.60155  ...
#
#       Total_expenditure  Diphtheria  HIV/AIDS       GDP  Population  \
# 1361           0.281509    0.978723       0.1  0.010219    0.180332
#
#       thinness__1_19_years  thinness_5_9_years  \
# 1361                  0.48                 0.5
#
#       Income_composition_of_resources  Schooling  Country_Status
# 1361                          0.71308   0.630208               0
#
# [1 rows x 22 columns]

# %%
#Income_composition_of_resources Outliers 
# Using Inter-Quartile Method
Q1 = data['Income_composition_of_resources'].quantile(0.25)
Q3 = data['Income_composition_of_resources'].quantile(0.75)
# Calculate IQR
IQR = Q3 - Q1
# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Identify outliers
outliers = data[(data['Income_composition_of_resources'] < lower_bound) | (data['Income_composition_of_resources'] > upper_bound)]

#printing outliers to see if not all data(for all years) for a country is deleted
print(outliers)
# Remove outliers
data = data[(data['Income_composition_of_resources'] >= lower_bound) & (data['Income_composition_of_resources'] <= upper_bound)]
# Out:
#                      Country  Year  Life_expectancy  Adult_Mortality  \
# 330   Bosnia and Herzegovina  2005         0.442231         0.037415
# 331   Bosnia and Herzegovina  2004         0.462151         0.333333
# 332   Bosnia and Herzegovina  2003         0.450199         0.037415
# 333   Bosnia and Herzegovina  2002         0.458167         0.034014
# 334   Bosnia and Herzegovina  2001         0.438247         0.380952
# 335   Bosnia and Herzegovina  2000         0.426295         0.391156
# 993                  Georgia  2000         0.314741         0.435374
# 1744              Montenegro  2003         0.382470         0.452381
# 1745              Montenegro  2002         0.378486         0.459184
# 1746              Montenegro  2001         0.374502         0.459184
# 1747              Montenegro  2000         0.362550         0.486395
#
#       infant_deaths   Alcohol  percentage_expenditure  Hepatitis_B   Measles  \
# 330        0.000000  0.254759                0.002347     0.721467  0.000538
# 331        0.000000  0.237402                0.000179     0.721467  0.000655
# 332        0.000000  0.231243                0.002046     0.721467  0.000421
# 333        0.000000  0.214446                0.007759     0.721467  0.000655
# 334        0.000000  0.215006                0.007356     0.721467  0.000000
# 335        0.000000  0.203247                0.008502     0.721467  0.001006
# 993        0.045455  0.183091                0.002455     0.779288  0.001170
# 1744       0.000000  0.000000                0.025415     0.481553  0.000000
# 1745       0.000000  0.000000                0.001873     0.481553  0.000000
# 1746       0.000000  0.000000                0.001728     0.481553  0.000000
# 1747       0.000000  0.000000                0.014094     0.481553  0.000000
#
#            BMI  ...  Total_expenditure  Diphtheria  HIV/AIDS       GDP  \
# 330   0.006202  ...           0.680773    0.936170       0.1  0.024808
# 331   0.694574  ...           0.763569    0.840426       0.1  0.002126
# 332   0.686822  ...           0.629255    0.872340       0.1  0.018483
# 333   0.677519  ...           0.551978    0.031915       0.1  0.014680
# 334   0.668217  ...           0.557498    0.914894       0.1  0.012690
# 335   0.658915  ...           0.625575    0.851064       0.1  0.012164
# 993   0.634109  ...           0.537259    0.031915       0.1  0.005704
# 1744  0.761240  ...           0.718491    0.930278       0.1  0.023304
# 1745  0.750388  ...           0.665133    0.930278       0.1  0.001712
# 1746  0.737984  ...           0.655934    0.930278       0.1  0.001572
# 1747  0.725581  ...           0.572217    0.930278       0.1  0.013554
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 330     0.004581                  0.52                0.54
# 331     0.045814                  0.54                0.56
# 332     0.045790                  0.54                0.56
# 333     0.004574                  0.56                0.58
# 334     0.045693                  0.58                0.60
# 335     0.004563                  0.60                0.60
# 993     0.000535                  0.56                0.58
# 1744    0.007418                  0.42                0.44
# 1745    0.000846                  0.44                0.46
# 1746    0.000816                  0.44                0.48
# 1747    0.000078                  0.46                0.50
#
#       Income_composition_of_resources  Schooling  Country_Status
# 330                               0.0   0.651042               0
# 331                               0.0   0.640625               0
# 332                               0.0   0.630208               0
# 333                               0.0   0.619792               0
# 334                               0.0   0.604167               0
# 335                               0.0   0.000000               0
# 993                               0.0   0.593750               0
# 1744                              0.0   0.000000               0
# 1745                              0.0   0.000000               0
# 1746                              0.0   0.000000               0
# 1747                              0.0   0.000000               0
#
# [11 rows x 22 columns]

# %%
#Schooling Outliers 
# Using Inter-Quartile Method
Q1 = data['Schooling'].quantile(0.25)
Q3 = data['Schooling'].quantile(0.75)
# Calculate IQR
IQR = Q3 - Q1
# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Identify outliers
outliers = data[(data['Schooling'] < lower_bound) | (data['Schooling'] > upper_bound)]
#printing outliers to see if not all data(for all years) for a country is deleted
print(outliers)
# Remove outliers
data = data[(data['Schooling'] >= lower_bound) & (data['Schooling'] <= upper_bound)]
# Out:
#         Country  Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# 159  Azerbaijan  2000          0.10757          0.05102       0.204545
#
#       Alcohol  percentage_expenditure  Hepatitis_B   Measles       BMI  ...  \
# 159  0.035834                0.001802      0.59251  0.004915  0.573643  ...
#
#      Total_expenditure  Diphtheria  HIV/AIDS       GDP  Population  \
# 159           0.328427    0.755319       0.1  0.005402    0.000102
#
#      thinness__1_19_years  thinness_5_9_years  \
# 159                  0.58                0.58
#
#      Income_composition_of_resources  Schooling  Country_Status
# 159                         0.670886   0.526042               0
#
# [1 rows x 22 columns]

# %%
without_outliers = data.copy()
without_outliers.drop('Year', axis=1, inplace=True)

show_boxplot(without_outliers)
# Out:
# c:\Users\SIYA\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
# DATA EXPLORATION

import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Selected Variables')
plt.show()
# Out:
# C:\Users\SIYA\AppData\Local\Temp\ipykernel_7804\2424890640.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
#data.to_csv('processed_data.csv', index=False)
data.count()
# Out:
# Country                            643
# Year                               643
# Life_expectancy                    643
# Adult_Mortality                    643
# infant_deaths                      643
# Alcohol                            643
# percentage_expenditure             643
# Hepatitis_B                        643
# Measles                            643
# BMI                                643
# under_five_deaths                  643
# Polio                              643
# Total_expenditure                  643
# Diphtheria                         643
# HIV/AIDS                           643
# GDP                                643
# Population                         643
# thinness__1_19_years               643
# thinness_5_9_years                 643
# Income_composition_of_resources    643
# Schooling                          643
# Country_Status                     643
# dtype: int64

# %%
# IV to DV exploration

from matplotlib import pyplot as plt
import numpy as np
plt.title("Adult Mortality v Life Expectancy")
plt.xlabel("Adult Mortality")
plt.ylabel("Life Expectancy")
plt.scatter(data['Adult_Mortality'], data['Life_expectancy'])
plt.plot(np.unique(data['Adult_Mortality']), np.poly1d(np.polyfit(data['Adult_Mortality'], data['Life_expectancy'], 1))(np.unique(data['Adult_Mortality'])))
#correlations
from scipy.stats import pearsonr
corr = pearsonr(data['Adult_Mortality'], data['Life_expectancy'])
print(corr)

# Adult Mortality v Life Expectancy
# The above suggests that there is a strong negative correlation (-0.609) between Adult Mortality and Life expectancy(As Adult Mortality increases, Life expectancy tends to decrease), and this relationship is statistically significant (p-value=1.14e-66 <0.05).
# Out:
# PearsonRResult(statistic=-0.6095574744792486, pvalue=1.1367804985941253e-66)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Year v Life Expectancy")
plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.scatter(data['Year'], data['Life_expectancy'])
plt.plot(np.unique(data['Year']), np.poly1d(np.polyfit(data['Year'], data['Life_expectancy'], 1))(np.unique(data['Year'])))
#correlations
from scipy.stats import pearsonr
corr = pearsonr(data['Year'], data['Life_expectancy'])
print(corr)

# Year v Life Expectancy
# Correlation between Year and Life Expectancy is approximately 0.269, and the associated p-value is very small (3.84e-12) which denotes a significant weak positive relationship.
# We also observe from the scatterplot that the relationship is not linear
# Out:
# PearsonRResult(statistic=0.2692518492230731, pvalue=3.84202884566702e-12)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Infant Deaths v Life Expectancy")
plt.xlabel("Infant Deaths")
plt.ylabel("Life Expectancy")
plt.scatter(data['infant_deaths'], data['Life_expectancy'])
plt.plot(np.unique(data['infant_deaths']), np.poly1d(np.polyfit(data['infant_deaths'], data['Life_expectancy'], 1))(np.unique(data['infant_deaths'])))
#correlations
corr = pearsonr(data['infant_deaths'], data['Life_expectancy'])
print(corr)

# Infant deaths v Life Expectancy
#PearsonRResult(statistic=-0.26408633718053565, pvalue=1.0126642350770811e-11)
# The Pearson correlation coefficient suggests a weak negative linear relationship between the variables, which is statistically significant.
# Out:
# PearsonRResult(statistic=-0.26408633718053565, pvalue=1.0126642350770811e-11)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Percentage Expenditure v Life Expectancy")
plt.xlabel("Percentage Expenditure")
plt.ylabel("Life Expectancy")
plt.scatter(data['percentage_expenditure'], data['Life_expectancy'])
plt.plot(np.unique(data['percentage_expenditure']), np.poly1d(np.polyfit(data['percentage_expenditure'], data['Life_expectancy'], 1))(np.unique(data['percentage_expenditure'])))
#correlations
from scipy.stats import pearsonr
corr = pearsonr(data['percentage_expenditure'], data['Life_expectancy'])
print(corr)

# Percentage Expenditure v Life Expectancy
# The Pearson correlation coefficient suggests a moderately strong positive linear relationship between the variables, with a statistically significant p-value (<0.05)
# Out:
# PearsonRResult(statistic=0.443957913028915, pvalue=1.961216863962891e-32)

# %%
#Hepatitis_B v Life_expectancy
corr = pearsonr(data['Hepatitis_B'], data['Life_expectancy'])
print(corr)

# PearsonRResult(statistic=-0.19308593520883818, pvalue=8.092020708806834e-07)
# This suggests a significant weak negative relationship between Hepatitis_B and Life_expectancy
# Out:
# PearsonRResult(statistic=-0.19308593520883818, pvalue=8.092020708806834e-07)

# %%
#'Measles' v Life_expectancy
from scipy.stats import pearsonr
corr = pearsonr(data['Measles'], data['Life_expectancy'])
print(corr)

# PearsonRResult(statistic=-0.12269233850863936, pvalue=0.0018276724420202793)
# This is a significant weak negative correlation
# Out:
# PearsonRResult(statistic=-0.12269233850863936, pvalue=0.0018276724420202793)

# %%
#'under_five_deaths' v Life_expectancy
corr = pearsonr(data['under_five_deaths'], data['Life_expectancy'])
print(corr)

# This is a significant weak negative correlation
# Out:
# PearsonRResult(statistic=-0.25575604701008703, pvalue=4.62646233179729e-11)

# %%
#'BMI' v Life_expectancy
corr = pearsonr(data['BMI'], data['Life_expectancy'])
print(corr)

# This is a very weak positive correlation(0.07560228271368512) but is not significant since p value (0.055353205043900365>0.05)
#Hence we delete this column.

data.drop(columns=['BMI'], inplace=True)
# Out:
# PearsonRResult(statistic=0.07560228271368512, pvalue=0.055353205043900365)

# %%
#'Polio' v Life_expectancy
corr = pearsonr(data['Polio'], data['Life_expectancy'])
print(corr)
# This is a significant weak correlation
# Out:
# PearsonRResult(statistic=0.14051034239620155, pvalue=0.0003518444136093035)

# %%
#'Total_expenditure' v Life_expectancy
corr = pearsonr(data['Total_expenditure'], data['Life_expectancy'])
print(corr)
# This is a significant weak correlation
# Out:
# PearsonRResult(statistic=0.22498902282801267, pvalue=8.014188425020356e-09)

# %%
#'Diphtheria' v Life_expectancy
corr = pearsonr(data['Diphtheria'], data['Life_expectancy'])
print(corr)
# This is a significant weak correlation
# Out:
# PearsonRResult(statistic=0.1310023759775056, pvalue=0.0008691397641876822)

# %%
#'HIV/AIDS' v Life_expectancy
corr = pearsonr(data['HIV/AIDS'], data['Life_expectancy'])
print(corr)
# This is a significant weak correlation
# Out:
# PearsonRResult(statistic=-0.248697248011982, pvalue=1.6076329134479544e-10)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("GDP v Life Expectancy")
plt.xlabel("GDP")
plt.ylabel("Life Expectancy")
plt.scatter(data['GDP'], data['Life_expectancy'])
plt.plot(np.unique(data['GDP']), np.poly1d(np.polyfit(data['GDP'], data['Life_expectancy'], 1))(np.unique(data['GDP'])))

#'GDP' v Life_expectancy
corr = pearsonr(data['GDP'], data['Life_expectancy'])
print(corr)

#This is a significant moderately strong positive correlation between GDP and Life_expectancy
# Out:
# PearsonRResult(statistic=0.46839739312034817, pvalue=2.235619354135492e-36)

# %%
#'Population' v Life_expectancy
corr = pearsonr(data['Population'], data['Life_expectancy'])
print(corr)
#The correlation coefficient of 0.097 indicates a very weak positive correlation, but it is statistically significant with a p-value of 0.014.
# Out:
# PearsonRResult(statistic=0.09713008409829782, pvalue=0.013739352586290651)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Thinness among children (1-19 yrs) v Life Expectancy")
plt.xlabel("Thinness among children (1-19 yrs)")
plt.ylabel("Life Expectancy")
plt.scatter(data['thinness__1_19_years'], data['Life_expectancy'])
plt.plot(np.unique(data['thinness__1_19_years']), np.poly1d(np.polyfit(data['thinness__1_19_years'], data['Life_expectancy'], 1))(np.unique(data['thinness__1_19_years'])))

#'thinness__1_19_years' v Life_expectancy
corr = pearsonr(data['thinness__1_19_years'], data['Life_expectancy'])
print(corr)

# The Pearson correlation coefficient is -0.6798, indicating a strong negative correlation between the variables. The p-value is (2.28931287895088e-88 <<0.05), indicating that this correlation is statistically significant.
# Out:
# PearsonRResult(statistic=-0.6797661275327486, pvalue=2.28931287895088e-88)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Thinness among children (5-9 yrs) v Life Expectancy")
plt.xlabel("Thinness among children (5-9 yrs)")
plt.ylabel("Life Expectancy")
plt.scatter(data['thinness_5_9_years'], data['Life_expectancy'])
plt.plot(np.unique(data['thinness_5_9_years']), np.poly1d(np.polyfit(data['thinness_5_9_years'], data['Life_expectancy'], 1))(np.unique(data['thinness_5_9_years'])))

#'thinness_5_9_years' v Life_expectancy
corr = pearsonr(data['thinness_5_9_years'], data['Life_expectancy'])
print(corr)

# This indicates a strong negative correlation between the variables. The p-value is << 0.05, indicating that this correlation is statistically significant.
# Out:
# PearsonRResult(statistic=-0.6955376652555266, pvalue=4.1768473790409724e-94)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Income composition of resources v Life Expectancy")
plt.xlabel("Income composition of resources")
plt.ylabel("Life Expectancy")
plt.scatter(data['Income_composition_of_resources'], data['Life_expectancy'])
plt.plot(np.unique(data['Income_composition_of_resources']), np.poly1d(np.polyfit(data['Income_composition_of_resources'], data['Life_expectancy'], 1))(np.unique(data['Income_composition_of_resources'])))

#'Income_composition_of_resources' v Life_expectancy
corr = pearsonr(data['Income_composition_of_resources'], data['Life_expectancy'])
print(corr)

# The Pearson correlation coefficient is 0.77, indicating a strong correlation between the variables. The p-value is (4.06e-88 <<0.05), indicating that this correlation is statistically significant. 
#evident from scatterplot it has a linear relationship.
# Out:
# PearsonRResult(statistic=0.7735942159213295, pvalue=4.060854277627762e-129)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.title("Number of years of Schooling v Life Expectancy")
plt.xlabel("Number of years of Schooling")
plt.ylabel("Life Expectancy")
plt.scatter(data['Schooling'], data['Life_expectancy'])
plt.plot(np.unique(data['Schooling']), np.poly1d(np.polyfit(data['Schooling'], data['Life_expectancy'], 1))(np.unique(data['Schooling'])))

#'Schooling' v Life_expectancy
corr = pearsonr(data['Schooling'], data['Life_expectancy'])
print(corr)

# The Pearson correlation coefficient is 0.55, indicating a moderately strong correlation between the variables. The p-value is (2.51e-54 <<0.05), indicating that this correlation is statistically significant.
# Out:
# PearsonRResult(statistic=0.5598709883442151, pvalue=2.5182440448545803e-54)

# %% [markdown]
# Inference from DV to IV relations
# <ul>
# <li>For 'BMI' and 'Life Expectancy' is a very weak positive insignificant correlation(0.075) with p value (0.05535>0.05).</li>
#
# <li>We observe strong significant(less than 0.05) correlations of Life Expectancy with: Thinness among children (1-19 yrs) with (r = -0.6798); Thinness among children (5-9 yrs) with (r=-0.695) </li>
#
# <li>Exteremely strong correlation of life expectancy with Income composition of resources (r=0.77)</li>
#
# <li> We observe moderately strong correlation of Life expectancy with
# GDP (r=0.46839),
# Percentage expenditure (r=0.443957), and
# Schooling (r=0.559)
# </li>
#
# <li>We have weak correlation of life expectancy with r values for
# Infant deaths (-0.264),
# Hepatitis_B (-0.193),
# Measles (-0.123),
# under_five_deaths (-0.255),
# Polio (0.14),
# Total expenditure (0.22),
# Diptheria (0.131),
# HIV/AIDS (-0.24)
# </li>
#
# <li>We observe very weak correlations of life expectancy with BMI and Population (r = 0.09)</li>
# </ul>
#
# Hence we delete BMI column.
#
# We keep the  Thinness among children (1-19 yrs); Thinness among children (5-9 yrs); Income composition of resources and further explore the remaining variables for multicollinearity.
#
# We also keep population since from the correlation matrix we see that it not strongly correlated with any other variables and hence will be a good variable to have.

# %%
#IV to IV relationship

#under_five_deaths - infant_deaths
corr = pearsonr(data['under_five_deaths'], data['infant_deaths'])
print(corr)

# GDP – percentage_expenditure
corr = pearsonr(data['GDP'], data['percentage_expenditure'])
print(corr)

# thinness_5_9_years - thinness__1_19_years
corr = pearsonr(data['thinness_5_9_years'], data['thinness__1_19_years'])
print(corr)

# Income_composition_of_resources - Schooling
corr = pearsonr(data['Income_composition_of_resources'], data['Schooling'])
print(corr)

#Diptheria - Polio
corr = pearsonr(data['Diphtheria'], data['Polio'])
print(corr)
# Out:
# PearsonRResult(statistic=0.9977039653263142, pvalue=0.0)
# PearsonRResult(statistic=0.9282927149889604, pvalue=1.369346442832172e-277)
# PearsonRResult(statistic=0.9940702049966889, pvalue=0.0)
# PearsonRResult(statistic=0.831227350829619, pvalue=1.37255319612826e-165)
# PearsonRResult(statistic=0.6636139943340088, pvalue=7.489838629344068e-83)

# %% [markdown]
# We observe a significant strong correlation betweeen following:<br>
#
# under_five_deaths - infant_deaths<br>
# We keep infant_deaths and delete under_five_deaths since it has a comparitvely higher correlation with Life Expectancy:
# Infant deaths (r = -0.264),
# under_five_deaths (r = -0.255),
#
# GDP – percentage_expenditure<br>
# We keep GDP and delete percentage_expenditure since it has a comparitvely higher correlation with Life Expectancy:
# GDP (r=0.46839),
# Percentage expenditure (r=0.443957)
#
# thinness_5_9_years - thinness__1_19_years<br>
# We keep Thinness among children (5-9 yrs) delete Thinness among children (1-19 yrs) since it has a comparitvely higher correlation with Life Expectancy:
# Thinness among children (1-19 yrs) with (r = -0.6798);
# Thinness among children (5-9 yrs) with (r=-0.695)
#
# Income_composition_of_resources - Schooling <br>
# We keep Income_composition_of_resources and delete Schooling since it has a comparitvely higher correlation with Life Expectancy:
# Income composition of resources (r=0.77)
# Schooling (r=0.559)
#
# Diphtheria - Polio<br>
# We keep Polio and delete Diptheria since it has a comparitvely higher correlation with Life Expectancy:
# Polio (0.14),
# Diphtheria (0.131)

# %%
# Drop specified columns
data.drop(columns=['under_five_deaths', 'percentage_expenditure', 'thinness__1_19_years', 'Schooling','Diphtheria'], inplace=True)

# %%
correlation_matrix = data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Selected Variables')
plt.show()
# Out:
# C:\Users\SIYA\AppData\Local\Temp\ipykernel_7804\231348352.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# Plot life expectancy over years for each country
# Group data by country
grouped_data = data.groupby('Country')
plt.figure(figsize=(12, 8))
for country, group in grouped_data:
    plt.plot(group['Year'], group['Life_expectancy'], label=country)

plt.title('Life Expectancy Over Years for Each Country')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.legend(loc='upper left', bbox_to_anchor=(0.5, -0.2), ncol=2)  # Adjust the bbox_to_anchor parameter
plt.grid(True)
plt.show()

# %%
developed_le = []
developed_ic = []
developing_le = []
developing_ic = []

for i in range(len(data['Country_Status'])):
    if data['Country_Status'].iloc[i] == 1:
        developed_le.append(data['Life_expectancy'].iloc[i])
        developed_ic.append(data['Income_composition_of_resources'].iloc[i])
    else:
        developing_le.append(data['Life_expectancy'].iloc[i])
        developing_ic.append(data['Income_composition_of_resources'].iloc[i])

# %%
legend_names = ["Developing", "Developed"]
plt.title("Life Expectancy v Income composition of Resources by Country Status")
plt.xlabel("Income_composition_of_resources")
plt.ylabel("Life_expectancy")
scatter = plt.scatter(data['Income_composition_of_resources'], data['Life_expectancy'], c = data['Country_Status'])
plt.plot(np.unique(developed_ic), np.poly1d(np.polyfit(developed_ic, developed_le, 1))(np.unique(developed_ic)))
plt.plot(np.unique(developing_ic), np.poly1d(np.polyfit(developing_ic, developing_le, 1))(np.unique(developing_ic)))
plt.legend(handles = scatter.legend_elements()[0], labels=legend_names, title="Country Status")

# %% [markdown]
# Principal Component Analysis

# %%
#keep unique countries and replace column values by average over the years
average_data = data.groupby('Country').mean()
average_data = average_data.drop(columns=['Year'])
df = pd.DataFrame(average_data).reset_index()
print(df)

#We observe total 40 countries stored in the format requireed to perform PCA
# Out:
#                    Country  Life_expectancy  Adult_Mortality  infant_deaths  \
# 0                  Albania         0.448456         0.149872       0.015625
# 1                  Armenia         0.378486         0.395833       0.022727
# 2                  Austria         0.700448         0.220238       0.000000
# 3               Azerbaijan         0.283134         0.410884       0.133333
# 4                  Belarus         0.239293         0.740646       0.012784
# 5                  Belgium         0.668576         0.235332       0.005682
# 6   Bosnia and Herzegovina         0.501594         0.226531       0.000000
# 7                 Bulgaria         0.356574         0.423469       0.021307
# 8                  Croatia         0.486803         0.299320       0.000000
# 9                   Cyprus         0.628486         0.180697       0.000000
# 10                 Czechia         0.512699         0.240859       0.000000
# 11                 Denmark         0.611803         0.221301       0.000000
# 12                 Estonia         0.439990         0.573767       0.000000
# 13                 Finland         0.669821         0.230867       0.000000
# 14                  France         0.729831         0.245323       0.066761
# 15                 Georgia         0.387251         0.384354       0.025758
# 16                 Germany         0.688247         0.238946       0.056818
# 17                  Greece         0.689990         0.247024       0.004261
# 18                 Hungary         0.395418         0.496811       0.012784
# 19                 Iceland         0.738795         0.164541       0.000000
# 20                 Ireland         0.647410         0.242985       0.000000
# 21                   Italy         0.728586         0.180910       0.045455
# 22              Kazakhstan         0.121647         0.772336       0.159091
# 23                  Latvia         0.391683         0.546981       0.000000
# 24               Lithuania         0.354831         0.395408       0.000000
# 25              Luxembourg         0.672560         0.226403       0.000000
# 26                   Malta         0.655876         0.203231       0.000000
# 27              Montenegro         0.438247         0.261338       0.000000
# 28             Netherlands         0.686504         0.206207       0.022727
# 29                  Norway         0.712898         0.221939       0.000000
# 30                  Poland         0.468127         0.362457       0.051136
# 31                Portugal         0.641185         0.196854       0.004261
# 32                 Romania         0.404382         0.527423       0.063920
# 33                  Serbia         0.400647         0.440264       0.022727
# 34                Slovakia         0.432271         0.398172       0.000000
# 35                Slovenia         0.630727         0.256590       0.000000
# 36                   Spain         0.723855         0.213010       0.036932
# 37                  Sweden         0.741783         0.197917       0.000000
# 38             Switzerland         0.734313         0.186224       0.000000
# 39                  Turkey         0.398904         0.331207       0.612216
# 40                 Ukraine         0.240538         0.696429       0.115057
#
#      Alcohol  Hepatitis_B   Measles     Polio  Total_expenditure  HIV/AIDS  \
# 0   0.270927     0.994175  0.001249  0.990385           0.445780    0.1000
# 1   0.206756     0.886084  0.006419  0.891484           0.358475    0.1000
# 2   0.684546     0.818770  0.001808  0.857143           0.345883    0.1000
# 3   0.056260     0.592510  0.014607  0.745788           0.435731    0.1000
# 4   0.755170     0.900324  0.000581  0.899725           0.473241    0.1000
# 5   0.617730     0.750809  0.001909  0.986264           0.453404    0.1000
# 6   0.258149     0.721467  0.011626  0.702198           0.728206    0.1000
# 7   0.607801     0.957929  0.035819  0.947802           0.563282    0.1000
# 8   0.696417     0.975764  0.000554  0.961538           0.574897    0.1000
# 9   0.573946     0.938511  0.000045  0.989011           0.522229    0.1000
# 10  0.728779     0.986778  0.000537  0.989011           0.547240    0.1000
# 11  0.598992     0.000000  0.000369  0.879121           0.613880    0.1000
# 12  0.504181     0.878533  0.000082  0.947802           0.429715    0.1000
# 13  0.534304     0.000000  0.000066  0.980082           0.682130    0.1000
# 14  0.693990     0.510032  0.062298  0.991758           0.504634    0.1000
# 15  0.323043     0.779288  0.032328  0.804396           0.573726    0.1000
# 16  0.650541     0.781230  0.035043  0.953984           0.290513    0.1000
# 17  0.492348     0.900324  0.000582  0.916896           0.718756    0.1000
# 18  0.639268     0.000000  0.000048  0.999313           0.609223    0.1000
# 19  0.417469     0.000000  0.000000  0.898352           0.676265    0.1000
# 20  0.707951     0.878533  0.004084  0.858516           0.605773    0.1000
# 21  0.462299     0.968285  0.045908  0.968407           0.696217    0.1000
# 22  0.373689     0.987055  0.030749  0.984615           0.286145    0.1000
# 23  0.495745     0.900324  0.000078  0.956731           0.485258    0.1000
# 24  0.706756     0.960518  0.000350  0.888049           0.503887    0.1000
# 25  0.666965     0.935922  0.000026  0.989698           0.590133    0.1000
# 26  0.398656     0.813343  0.000051  0.894918           0.680635    0.1000
# 27  0.192183     0.481553  0.000020  0.853452           0.554477    0.1000
# 28  0.494774     0.478447  0.005897  0.975962           0.555117    0.1000
# 29  0.348509     0.973463  0.000148  0.934753           0.722838    0.1000
# 30  0.559276     0.987702  0.001110  0.975275           0.489397    0.1000
# 31  0.683165     0.886731  0.000170  0.972527           0.625092    0.1000
# 32  0.501605     0.930097  0.031965  0.953297           0.394411    0.1000
# 33  0.485592     0.919094  0.001728  0.951923           0.473816    0.1000
# 34  0.585853     1.000000  0.000006  0.993819           0.575357    0.1000
# 35  0.601605     0.000000  0.000142  0.958104           0.702944    0.1000
# 36  0.560694     0.937217  0.010530  0.975275           0.675460    0.1000
# 37  0.387271     0.592362  0.000443  0.992445           0.795860    0.1000
# 38  0.578275     0.724919  0.009304  0.960165           0.464213    0.1000
# 39  0.079022     0.880906  0.123419  0.800137           0.423735    0.1000
# 40  0.412057     0.544984  0.126280  0.807005           0.523724    0.5375
#
#          GDP  Population  thinness_5_9_years  Income_composition_of_resources  \
# 0   0.017686    0.008443            0.300000                         0.748813
# 1   0.016681    0.012299            0.382500                         0.736682
# 2   0.283779    0.078450            0.347500                         0.909678
# 3   0.029096    0.027874            0.546667                         0.745921
# 4   0.031883    0.077202            0.427500                         0.784019
# 5   0.141851    0.034943            0.131250                         0.925897
# 6   0.021485    0.023417            0.474000                         0.760127
# 7   0.041345    0.064105            0.391250                         0.796018
# 8   0.075902    0.014052            0.303750                         0.832344
# 9   0.116537    0.004728            0.160000                         0.878758
# 10  0.133420    0.062739            0.372500                         0.845238
# 11  0.277400    0.051615            0.147500                         0.949235
# 12  0.069890    0.009594            0.387500                         0.868473
# 13  0.211953    0.042322            0.121250                         0.920820
# 14  0.221997    0.334185            0.080000                         0.918315
# 15  0.018830    0.000095            0.536000                         0.762799
# 16  0.204140    0.469591            0.181250                         0.943565
# 17  0.137982    0.018782            0.106250                         0.888515
# 18  0.071344    0.019445            0.342500                         0.848431
# 19  0.252997    0.002255            0.140000                         0.933874
# 20  0.283844    0.043615            0.003750                         0.940401
# 21  0.178100    0.334937            0.065000                         0.905129
# 22  0.035378    0.095770            0.466667                         0.790788
# 23  0.066629    0.014231            0.446250                         0.835970
# 24  0.075488    0.023338            0.553750                         0.850936
# 25  0.446832    0.003214            0.142500                         0.926292
# 26  0.084781    0.002723            0.102500                         0.855683
# 27  0.048845    0.004562            0.373333                         0.821027
# 28  0.293322    0.118444            0.152500                         0.949103
# 29  0.230132    0.031676            0.100000                         0.982529
# 30  0.056900    0.194504            0.432500                         0.857793
# 31  0.097233    0.012506            0.067500                         0.849156
# 32  0.035638    0.111545            0.661250                         0.804457
# 33  0.030734    0.043718            0.445000                         0.782371
# 34  0.133420    0.065311            0.245000                         0.847376
# 35  0.095911    0.004861            0.318750                         0.907634
# 36  0.143346    0.321598            0.060000                         0.897218
# 37  0.246078    0.066819            0.221250                         0.942115
# 38  0.481289    0.071645            0.038750                         0.961036
# 39  0.033330    0.405909            0.930000                         0.741891
# 40  0.013134    0.121221            0.495000                         0.755868
#
#     Country_Status
# 0              0.0
# 1              0.0
# 2              1.0
# 3              0.0
# 4              0.0
# 5              1.0
# 6              0.0
# 7              1.0
# 8              1.0
# 9              1.0
# 10             1.0
# 11             1.0
# 12             0.0
# 13             0.0
# 14             0.0
# 15             0.0
# 16             1.0
# 17             0.0
# 18             1.0
# 19             1.0
# 20             1.0
# 21             1.0
# 22             0.0
# 23             1.0
# 24             1.0
# 25             1.0
# 26             1.0
# 27             0.0
# 28             1.0
# 29             1.0
# 30             1.0
# 31             1.0
# 32             1.0
# 33             0.0
# 34             1.0
# 35             1.0
# 36             1.0
# 37             1.0
# 38             1.0
# 39             0.0
# 40             0.0

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# Extracting numerical columns
numerical_columns = df.columns[1:]

# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[numerical_columns])

# Perform PCA
pca = PCA()
pca.fit(scaled_data)

# Compute Eigenvectors
eigenvectors = pca.components_

# Select the number of components based on explained variance
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance_ratio.cumsum()

# Choose the number of components that explain a desired amount of variance
desired_variance_explained = 0.95  # You can adjust this threshold
n_components = (cumulative_explained_variance < desired_variance_explained).sum() + 1

# Perform PCA with the selected number of components
pca = PCA(n_components=n_components)
pca_data = pca.fit_transform(scaled_data)

# Create DataFrame for the PCA results
pca_columns = [f"PC{i+1}" for i in range(n_components)]
pca_df = pd.DataFrame(data=pca_data, columns=pca_columns)

# Concatenate with the country column
pca_df = pd.concat([df[['Country']], pca_df], axis=1)

# Interpret Eigenvectors
eigenvectors_df = pd.DataFrame(eigenvectors, columns=numerical_columns)

# Print Eigenvectors
print("Eigenvectors:")
print(eigenvectors_df)

# Features to include in the biplot
features_to_plot = ['Life_expectancy', 'Adult_Mortality', 'Alcohol']

# Plot biplot
plt.figure(figsize=(10, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], alpha=0.6)

# Plot eigenvectors for selected features as arrows
for feature in features_to_plot:
    feature_index = numerical_columns.get_loc(feature)
    comp = eigenvectors[:, feature_index]
    var = pca.explained_variance_[0]
    plt.arrow(0, 0, comp[0]*np.sqrt(var), comp[1]*np.sqrt(var), 
              head_width=0.1, head_length=0.1, color='r', alpha=0.75)
    plt.text(comp[0]*np.sqrt(var)*1.2, comp[1]*np.sqrt(var)*1.2, feature, color='g')

# Features to include in the biplot
features_to_plot = ['infant_deaths', 'Hepatitis_B', 'Polio']

# Plot biplot
plt.figure(figsize=(10, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], alpha=0.6)

# Plot eigenvectors for selected features as arrows
for feature in features_to_plot:
    feature_index = numerical_columns.get_loc(feature)
    comp = eigenvectors[:, feature_index]
    var = pca.explained_variance_[0]
    plt.arrow(0, 0, comp[0]*np.sqrt(var), comp[1]*np.sqrt(var), 
              head_width=0.1, head_length=0.1, color='r', alpha=0.75)
    plt.text(comp[0]*np.sqrt(var)*1.2, comp[1]*np.sqrt(var)*1.2, feature, color='g')

# Set labels
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Biplot')

# Show plot
plt.grid()
plt.show()
# Out:
# Eigenvectors:
#     Life_expectancy  Adult_Mortality  infant_deaths   Alcohol  Hepatitis_B  \
# 0         -0.364571         0.293738       0.260875 -0.235054     0.094404
# 1          0.267324        -0.207705       0.435481 -0.096815    -0.072502
# 2          0.130538        -0.257758      -0.038306 -0.427365    -0.424003
# 3         -0.116598         0.346323      -0.212433  0.336217    -0.331739
# 4         -0.100802         0.191429       0.158196  0.031023    -0.737303
# 5         -0.080226         0.011780       0.215412  0.114005    -0.231612
# 6         -0.050443        -0.041754       0.072394  0.107883     0.091281
# 7          0.060402        -0.009512      -0.254941  0.560325    -0.072534
# 8          0.109456        -0.453744      -0.295858 -0.152621    -0.252885
# 9         -0.101104         0.468933      -0.276169 -0.509789     0.030022
# 10        -0.268868         0.052843       0.355332  0.067722    -0.094310
# 11         0.348387         0.114158       0.346007  0.080826     0.091101
# 12         0.234780         0.175508      -0.363335 -0.075488    -0.008837
# 13        -0.686449        -0.416138      -0.110659  0.011678     0.055001
#
#      Measles     Polio  Total_expenditure  HIV/AIDS       GDP  Population  \
# 0   0.252820 -0.224361          -0.206979  0.159822 -0.322913    0.044807
# 1   0.493071 -0.074220          -0.008803  0.160172  0.232829    0.563385
# 2  -0.028123 -0.442978           0.451154  0.092362 -0.011602   -0.283767
# 3   0.236364  0.050177           0.105914  0.699999  0.060609   -0.102768
# 4  -0.129426  0.107107          -0.366933 -0.338838  0.176641    0.013386
# 5   0.046529  0.205915           0.527565 -0.162273 -0.405862    0.099814
# 6  -0.030913 -0.586996          -0.202642  0.041100  0.314572   -0.238145
# 7  -0.048609 -0.520045           0.070057 -0.218693 -0.238141    0.414057
# 8  -0.037800  0.058069          -0.491411  0.246003 -0.401831    0.131829
# 9  -0.184803 -0.178321           0.041284 -0.027157 -0.085541    0.410383
# 10  0.074374 -0.174141          -0.082228 -0.149281 -0.080920   -0.125529
# 11 -0.101133 -0.104848          -0.162664  0.104999 -0.540756   -0.274314
# 12  0.719932  0.000338          -0.079522 -0.401831 -0.092721   -0.271803
# 13  0.210777  0.005708           0.025598 -0.059832 -0.098845   -0.023040
#
#     thinness_5_9_years  Income_composition_of_resources  Country_Status
# 0             0.367352                        -0.378418       -0.285518
# 1            -0.039583                         0.181846        0.022714
# 2            -0.045393                        -0.040710       -0.243242
# 3            -0.105340                         0.101625        0.054619
# 4             0.171784                         0.171287       -0.125242
# 5             0.299646                        -0.077894        0.510506
# 6             0.331661                         0.082877        0.556499
# 7            -0.024888                        -0.058375       -0.233055
# 8            -0.033690                        -0.203437        0.281407
# 9            -0.168896                         0.310129        0.252972
# 10           -0.767168                        -0.244431        0.222880
# 11           -0.043180                         0.543578       -0.085612
# 12           -0.018063                         0.026521        0.081781
# 13            0.003833                         0.522083       -0.092888

# %% [markdown]
# From the above Bi-plots we understand that:
# <ul>
# <li>
# The arrows for life expectancy and adult mortality are in opposite directions, indicating a negative correlation between them. This suggests that countries with higher life expectancy tend to have lower adult mortality rates.</li>
# <li>
# The vector representing alcohol is shorter compared to the vectors representing life expectancy and adult mortality, it indicates that alcohol consumption has lower variance compared to them, with life expectancy having highest variance comparitively.
# </li>
# <li> From the second bi-plot we observe Polio and Hepatitis B have very lower variance.
# </li>
# </ul>

# %%
# Print the PCA DataFrame
print("\nPCA DataFrame:")
print(pca_df)
# Out:
# PCA DataFrame:
#                    Country       PC1       PC2       PC3       PC4       PC5  \
# 0                  Albania  1.281855 -1.154171  0.253901 -1.485113 -0.629990
# 1                  Armenia  2.681821 -1.329569  0.363379 -1.093157  0.095998
# 2                  Austria -1.287606  0.384968 -0.778094 -0.272269  0.452973
# 3               Azerbaijan  3.944366 -0.486191  2.077568 -1.256718  0.721279
# 4                  Belarus  2.406268 -2.009618 -1.471475  0.860205  0.520122
# 5                  Belgium -1.795500 -0.159124 -0.812025  0.000724  0.147220
# 6   Bosnia and Herzegovina  1.967433 -0.640299  3.297908 -1.015436 -1.084068
# 7                 Bulgaria  1.052707 -0.720216 -1.062189  0.292899 -0.684228
# 8                  Croatia -0.472902 -1.171123 -0.881717  0.023096 -0.770423
# 9                   Cyprus -1.482984 -0.560911 -0.567897 -0.385346 -0.681620
# 10                 Czechia -0.800316 -0.729685 -1.278777 -0.107079 -0.567982
# 11                 Denmark -2.335204  0.412839  1.417325  0.921162  1.582023
# 12                 Estonia  1.215241 -1.462389 -0.733834  0.142781  0.610383
# 13                 Finland -1.913412  0.122625  1.792263  0.737612  1.560759
# 14                  France -1.074289  2.776143 -0.779005  0.471729  0.745517
# 15                 Georgia  2.728939 -0.830369  1.531618 -0.490313 -0.334601
# 16                 Germany -1.077170  2.935392 -2.461138 -0.329907  0.679213
# 17                  Greece -1.103443 -0.306522  1.263285 -0.357051 -0.982318
# 18                 Hungary -0.275254 -1.258190  0.057248  1.467111  1.869116
# 19                 Iceland -2.524812  0.434143  2.294715  0.438562  1.161724
# 20                 Ireland -2.382659  0.242019  0.096522  0.297076 -0.638906
# 21                   Italy -1.616982  2.447406 -0.356456 -0.459191 -1.400739
# 22              Kazakhstan  3.994599 -0.857371 -2.159646 -0.010212  1.200990
# 23                  Latvia  0.869563 -1.551325 -1.098833  0.162743  0.108997
# 24               Lithuania  0.690027 -1.390725 -1.044556  0.130950 -0.170608
# 25              Luxembourg -2.952959  0.181184 -0.637316  0.175879 -0.225667
# 26                   Malta -1.174003 -0.456802  1.210034 -0.503739 -1.173956
# 27              Montenegro  1.309244 -0.893560  2.153525 -0.732639  0.450148
# 28             Netherlands -2.344477  0.950452  0.110284  0.085203  0.732976
# 29                  Norway -2.424980  0.319637  0.880752 -0.469857 -1.109954
# 30                  Poland  0.338404 -0.110328 -1.581253 -0.473144 -0.214890
# 31                Portugal -1.708647 -0.638433 -0.279763 -0.036116 -1.034730
# 32                 Romania  2.110680 -0.398805 -1.745664 -0.130494  0.309515
# 33                  Serbia  1.771953 -1.377974 -0.475352 -0.398091  0.062704
# 34                Slovakia -0.454089 -0.960118 -1.169783  0.094623 -0.567261
# 35                Slovenia -1.680594 -0.430245  1.328032  0.913908  1.228763
# 36                   Spain -1.879876  1.553265 -0.648314 -0.462650 -1.130573
# 37                  Sweden -2.589619  0.478575  1.190137 -0.100793 -0.343578
# 38             Switzerland -3.171642  1.137787 -0.477278  0.110432  0.520426
# 39                  Turkey  6.536553  5.381109  0.173034 -2.436969  0.650699
# 40                 Ukraine  5.623767  2.126522  1.008834  5.679587 -1.665451
#
#          PC6       PC7       PC8       PC9
# 0  -0.806953 -1.380651 -0.855895  1.198316
# 1  -1.205327 -0.432112 -0.423357  0.868274
# 2  -1.292648  1.974173  0.609608  0.548193
# 3  -0.657676  0.833877 -0.074246  0.281796
# 4  -0.263700 -0.356791  1.447113 -1.230457
# 5  -0.306604  0.050876 -0.331735  0.690479
# 6  -0.007234  0.637609  1.459300 -0.140610
# 7   1.064835  0.206803  0.093294 -0.056904
# 8   0.685895  0.242901  0.180006  0.097181
# 9  -0.012036 -0.047553 -0.508493  0.635916
# 10  0.569902  0.283871  0.113817  0.181285
# 11  0.171296  0.835844  0.403067  0.085149
# 12 -0.943742 -0.588879  0.013234 -0.582389
# 13 -0.161581 -1.551365  0.141534 -0.319151
# 14 -0.795924 -1.784233  1.111505 -0.126957
# 15 -0.144266  0.255183  0.587758 -0.205807
# 16 -0.737128 -0.004173  1.116236  1.283408
# 17 -0.627246 -1.083796  0.367081 -0.931605
# 18  1.779026 -0.396783 -0.094223  0.143956
# 19  0.360443  0.444786 -0.339883  0.328560
# 20 -0.753656  1.104197  0.678632 -0.733197
# 21  0.599913 -0.906269  0.252009 -0.038537
# 22 -0.655226 -0.799470 -0.935420 -0.815550
# 23  0.520488  0.466756 -0.508495 -0.079235
# 24  0.626328  1.396458  0.639912 -0.117639
# 25 -0.919435  0.798786 -0.890515 -1.105098
# 26  0.417455  0.092027 -0.175506  0.318444
# 27 -0.504502 -0.379469 -0.052446  0.529268
# 28 -0.198889  0.128533 -0.609915  0.135577
# 29 -0.097016  0.175212 -0.919647 -0.761650
# 30  0.774178  0.043468  0.089931  0.388991
# 31  0.464875 -0.295013  0.125725  0.284464
# 32  0.837953  0.711708 -0.328814  0.355290
# 33 -0.373510 -0.814498  0.138082 -0.075936
# 34  0.458192 -0.118319 -0.378011 -0.294663
# 35  1.680747 -0.130476  0.120467  0.374195
# 36  0.658972 -0.937716  0.621183  0.097382
# 37  0.877980 -0.378467 -0.960344 -0.564674
# 38 -1.722256  0.934412 -0.818115 -0.358519
# 39  1.300663  0.610649 -0.557547 -0.802222
# 40 -0.662588  0.157903 -0.546889  0.514674

# %%
per_var = np.round(pca.explained_variance_ratio_*100, decimals=1)

labels=['PC'+str(i) for i in range(1, len(per_var)+1)]
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel("Percentage of Explained Variance")
plt.xlabel("Principal Components")
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# PC1 has the highest eigenvalue and the eigenvalues decrease as we move to further components, it suggests that PC1 accounts for the most variance in the data, followed by PC2, PC3, and so on.
#
# This suggests retaining fewer components simplifies the dataset while preserving most of its variability, making it easier to interpret and analyze.
#
# Hence we use PC1 for best results in variance and simplicity

# %%
# Get loading scores for PC1
loading_scores = pd.Series(pca.components_[0], index=numerical_columns)

# Sort the loading scores by absolute value in descending order
loading_scores_sorted = loading_scores.abs().sort_values(ascending=False)

# Print the loading scores
print("Loading Scores for PC1:")
print(loading_scores_sorted)
# Out:
# Loading Scores for PC1:
# Income_composition_of_resources    0.378418
# thinness_5_9_years                 0.367352
# Life_expectancy                    0.364571
# GDP                                0.322913
# Adult_Mortality                    0.293738
# Country_Status                     0.285518
# infant_deaths                      0.260875
# Measles                            0.252820
# Alcohol                            0.235054
# Polio                              0.224361
# Total_expenditure                  0.206979
# HIV/AIDS                           0.159822
# Hepatitis_B                        0.094404
# Population                         0.044807
# dtype: float64

# %% [markdown]
# From the loading scores we infer that
# Income_composition_of_resources, thinness_5_9_years, Life_expectancy, and GDP
# should have more weight compared to other variables
# <br><br>
# We drop Population since it has a very low loading score indicating low contribution to variance and little influence on PC1.

# %%
# From loading scores I am attempting to remove Population to incorporate dimensionality reduction
data.drop(columns=['Population'], inplace=True)

# %% [markdown]
# CLUSTERING
# <br><br>
# I chose Hierarchial Clustering because
# <ul>
# <li>No need to specify the number of clusters: Hierarchical clustering builds a tree-like structure (dendrogram) that allows you to visualize the clustering process at different levels of granularity which is useful in this case as we are unsure about the appropriate number of clusters in the data.</li>
# <li>Robustness to outliers: My data includes some outliers and Hierarchical clustering can handle outliers gracefully, since it's based on the distance between data points, outliers typically don't affect the overall clustering structure as much as in other methods like k-means. </li>
# <li>Interpretability: The dendrogram produced by hierarchical clustering provides a clear visual representation of how the data points are grouped together, which helps to identify structure of data.</li>
# <li>Flexibility in linkage methods: Hierarchical clustering allows to choose different linkage methods (e.g., single, complete, average, etc.) depending on desired clustering outcome.</li>
# <li>Suitable for small datasets: Since hierarchical clustering compares all pairs of data points, it can be computationally expensive for large datasets. However, for small to moderate-sized datasets, the computational overhead is typically manageable.</li></ul>

# %%
import scipy.cluster.hierarchy as sch

X_subset = df['Life_expectancy'].values.reshape(-1, 1)
labels = df['Country']

plt.figure(figsize=(6, 14))
dendrogram = sch.dendrogram(sch.linkage(X_subset, method='complete',metric='euclidean'), labels=labels.values)
plt.title('Life expectancy Hierarchical Clustering Dendrogram')
plt.xlabel('Countries')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# I used complete linkage because it resulted in relatively compact and well-separated clusters. Also the maximum distance for single and average is 0.3 while for complete max distance of clustering is 0.6 hence prioritizing variance and maintaining distinctiveness.

# %%
from sklearn.cluster import AgglomerativeClustering

features = df[['GDP', 'Income_composition_of_resources']]

# Scale the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
# Perform agglomerative hierarchical clustering
hc = AgglomerativeClustering(n_clusters=4, linkage='complete')
cluster_labels = hc.fit_predict(features_scaled)

# Add country annotations
plt.figure(figsize=(10, 6))
plt.scatter(features_scaled[cluster_labels==0, 0], features_scaled[cluster_labels==0, 1], s=100, c='cyan', label='Cluster 0')
plt.scatter(features_scaled[cluster_labels==1, 0], features_scaled[cluster_labels==1, 1], s=100, c='yellow', label='Cluster 1')
plt.scatter(features_scaled[cluster_labels==2, 0], features_scaled[cluster_labels==2, 1], s=100, c='red', label='Cluster 2')
plt.scatter(features_scaled[cluster_labels==3, 0], features_scaled[cluster_labels==3, 1], s=100, c='green', label='Cluster 3')

for i, country in enumerate(df['Country']):
    plt.annotate(country, (features_scaled[i, 0], features_scaled[i, 1]))

plt.xlabel('GDP')
plt.ylabel('Income_composition_of_resources')
plt.title('Countries GDP v Income Clustering')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Switzerland and Luxembourg are grouped together in a cluster characterized by higher values for GDP and income composition of resources. This suggests that these countries share similar economic profiles with strong GDP indicators and high levels of income composition, potentially indicating substanial economies and developed nations.
# <br><br>
# Also, Norway's relatively lower GDP might be a defining factor in its grouping with Italy, despite its higher income composition. This suggests that the clustering algorithm is considering both GDP and income composition of resources as important factors in grouping countries, leading to Norway's placement in a separate cluster with Italy due to their similar GDP profiles.

# %%
from sklearn.cluster import AgglomerativeClustering

features = df[['Life_expectancy', 'Adult_Mortality']]
# Scale the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform agglomerative hierarchical clustering
hc = AgglomerativeClustering(n_clusters=4, linkage='complete')
cluster_labels = hc.fit_predict(features_scaled)

# Add country annotations
plt.figure(figsize=(10, 6))
plt.scatter(features_scaled[cluster_labels==0, 0], features_scaled[cluster_labels==0, 1], s=100, c='cyan', label='Cluster 0')
plt.scatter(features_scaled[cluster_labels==1, 0], features_scaled[cluster_labels==1, 1], s=100, c='yellow', label='Cluster 1')
plt.scatter(features_scaled[cluster_labels==2, 0], features_scaled[cluster_labels==2, 1], s=100, c='red', label='Cluster 2')
plt.scatter(features_scaled[cluster_labels==3, 0], features_scaled[cluster_labels==3, 1], s=100, c='green', label='Cluster 3')

for i, country in enumerate(df['Country']):
    plt.annotate(country, (features_scaled[i, 0], features_scaled[i, 1]))

plt.xlabel('Life Expectancy')
plt.ylabel('Adult Mortality')
plt.title('Life expectancy v Adult Mortality Clustering')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This clustering validates the inverse correlation between life expectancy and adult mortality, indicating that countries with better healthcare systems and socio-economic conditions tend to have lower mortality rates and higher life expectancies like Switzerland, France grouped together in one cluster. Compared to Eastern Europe countries like Ukraine with low life expectancy and high adult mortality.

# %%
from sklearn.cluster import AgglomerativeClustering

features = df[['Life_expectancy', 'Income_composition_of_resources']]
# Scale the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform agglomerative hierarchical clustering
hc = AgglomerativeClustering(n_clusters=4, linkage='complete')
cluster_labels = hc.fit_predict(features_scaled)

# Add country annotations
plt.figure(figsize=(10, 6))
plt.scatter(features_scaled[cluster_labels==0, 0], features_scaled[cluster_labels==0, 1], s=100, c='cyan', label='Cluster 0')
plt.scatter(features_scaled[cluster_labels==1, 0], features_scaled[cluster_labels==1, 1], s=100, c='yellow', label='Cluster 1')
plt.scatter(features_scaled[cluster_labels==2, 0], features_scaled[cluster_labels==2, 1], s=100, c='red', label='Cluster 2')
plt.scatter(features_scaled[cluster_labels==3, 0], features_scaled[cluster_labels==3, 1], s=100, c='green', label='Cluster 3')

for i, country in enumerate(df['Country']):
    plt.annotate(country, (features_scaled[i, 0], features_scaled[i, 1]))

plt.xlabel('Life Expectancy')
plt.ylabel('Income composition of resources')
plt.title('Life expectancy v Income composition Clustering')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The clustering of countries like Azerbaijan, Belarus, Kazakhstan, and Ukraine in Eastern Europe suggests that they share common socio-economic and health-related challenges distinct from those in Western Europe. Historically, these regions have undergone significant economic transformations and healthcare system reforms, often following the dissolution of the Soviet Union. This reflects lower income composition and life expectancies.
#
# On the other hand, countries like Norway, Italy, and Spain, which are situated in Western Europe, are clustered separately, indicating higher income levels and life expectancies. This clustering validates the high loading score that income composition received from the PCA.

# %% [markdown]
# WEIGHING AND AGGREGATION - INDEX CREATION
# <br>
# Based on loading scores obtained from PCA
# We assign: <br><i>Income_composition_of_resources, thinness_5_9_years, Life_expectancy, GDP</i> <br>comparitively more weightage compared to other variables.

# %%
import pandas as pd

# Loading scores for each variable
loading_scores = {
    'Income_composition_of_resources': 0.378418,
    'thinness_5_9_years': 0.367352,
    'Life_expectancy': 0.364571,
    'GDP': 0.322913,
    'Adult_Mortality': 0.293738,
    'Country_Status': 0.285518,
    'infant_deaths': 0.260875,
    'Measles': 0.252820,
    'Alcohol': 0.235054,
    'Polio': 0.224361,
    'Total_expenditure': 0.206979,
    'HIV/AIDS': 0.159822,
    'Hepatitis_B': 0.094404
}

# Normalize weights
total_weight = sum(loading_scores.values())
normalized_weights = {key: value / total_weight for key, value in loading_scores.items()}

# Printing normalized weights
print("Normalized Weights:")
for indicator, weight in normalized_weights.items():
    print(f"{indicator}: {weight}")

# Weighting each indicator for each country
weighted_indicators = pd.DataFrame()
for col in normalized_weights:
    weighted_indicators[col] = df[col] * normalized_weights[col]

# Creating sub-indicators for each country
sub_indicators = pd.DataFrame()
sub_indicators['Country'] = df['Country']  # Adding country column at first
sub_indicators['Economic_Status'] = (weighted_indicators['Income_composition_of_resources'] + 
                                            weighted_indicators['GDP'] + 
                                            weighted_indicators['Total_expenditure'])
sub_indicators['Mortality'] = (weighted_indicators['Adult_Mortality'] + 
                                          weighted_indicators['infant_deaths'])
sub_indicators['Disease_Burden'] = (weighted_indicators['Measles'] + 
                               weighted_indicators['Polio'] + 
                               weighted_indicators['HIV/AIDS'] + 
                               weighted_indicators['Hepatitis_B'])
sub_indicators['Health_and_Lifestyle'] = (weighted_indicators['Life_expectancy'] + 
                                          weighted_indicators['Alcohol'] + 
                                          weighted_indicators['thinness_5_9_years'])
sub_indicators['Development_Status'] = weighted_indicators['Country_Status']

# Calculating the average of each sub-indicator for each country
sub_indicators['Health_quality_index'] = sub_indicators.drop(columns=['Country']).sum(axis=1)

print(sub_indicators)
# Out:
# Normalized Weights:
# Income_composition_of_resources: 0.10978741305404248
# thinness_5_9_years: 0.1065769222400325
# Life_expectancy: 0.10577009276653151
# GDP: 0.09368418762194193
# Adult_Mortality: 0.08521987626293763
# Country_Status: 0.08283507285690454
# infant_deaths: 0.07568559471397591
# Measles: 0.0733486614493048
# Alcohol: 0.06819435277392963
# Polio: 0.06509207749160459
# Total_expenditure: 0.06004917569067185
# HIV/AIDS: 0.04636788928941852
# Hepatitis_B: 0.0273886837887041
#                    Country  Economic_Status  Mortality  Disease_Burden  \
# 0                  Albania         0.110636   0.013955        0.096424
# 1                  Armenia         0.103967   0.035453        0.087405
# 2                  Austria         0.147227   0.018769        0.082988
# 3               Azerbaijan         0.110784   0.045107        0.070481
# 4                  Belarus         0.117480   0.064085        0.087903
# 5                  Belgium         0.142168   0.020485        0.089538
# 6   Bosnia and Herzegovina         0.129193   0.019305        0.070957
# 7                 Bulgaria         0.125091   0.037701        0.095195
# 8                  Croatia         0.133014   0.025508        0.093991
# 9                   Cyprus         0.138754   0.015399        0.094721
# 10                 Czechia         0.138157   0.020526        0.096079
# 11                 Denmark         0.167065   0.018859        0.061888
# 12                 Estonia         0.127699   0.048896        0.090399
# 13                 Finland         0.161912   0.019674        0.068437
# 14                  France         0.151920   0.025959        0.087731
# 15                 Georgia         0.119962   0.034704        0.080711
# 16                 Germany         0.140161   0.024663        0.090701
# 17                  Greece         0.153635   0.021374        0.089021
# 18                 Hungary         0.136414   0.043306        0.069688
# 19                 Iceland         0.166839   0.014022        0.063112
# 20                 Ireland         0.166212   0.020707        0.084881
# 21                   Italy         0.157864   0.018857        0.097560
# 22              Kazakhstan         0.107316   0.077859        0.098017
# 23                  Latvia         0.127160   0.046614        0.091577
# 24               Lithuania         0.130752   0.033697        0.088775
# 25              Luxembourg         0.178993   0.019294        0.094694
# 26                   Malta         0.142757   0.017319        0.085169
# 27              Montenegro         0.128010   0.022271        0.073380
# 28             Netherlands         0.165014   0.019293        0.081701
# 29                  Norway         0.172835   0.018914        0.092154
# 30                  Poland         0.128893   0.034759        0.095253
# 31                Portugal         0.139872   0.017098        0.092239
# 32                 Romania         0.115342   0.049785        0.094508
# 33                  Serbia         0.117226   0.039239        0.091899
# 34                Slovakia         0.140080   0.033932        0.096716
# 35                Slovenia         0.150843   0.021867        0.067012
# 36                   Spain         0.152493   0.020948        0.094561
# 37                  Sweden         0.174277   0.016866        0.085494
# 38             Switzerland         0.178474   0.015870        0.087673
# 39                  Turkey         0.110018   0.074561        0.089899
# 40                 Ukraine         0.115664   0.068058        0.101641
#
#     Health_and_Lifestyle  Development_Status  Health_quality_index
# 0               0.097882            0.000000              0.318896
# 1               0.094898            0.000000              0.321723
# 2               0.157804            0.082835              0.489622
# 3               0.092046            0.000000              0.318418
# 4               0.122370            0.000000              0.391838
# 5               0.126829            0.082835              0.461855
# 6               0.121175            0.000000              0.340631
# 7               0.120862            0.082835              0.461683
# 8               0.131354            0.082835              0.466701
# 9               0.122667            0.082835              0.454376
# 10              0.143627            0.082835              0.481225
# 11              0.121278            0.082835              0.451925
# 12              0.122219            0.000000              0.389213
# 13              0.120206            0.000000              0.370230
# 14              0.133047            0.000000              0.398657
# 15              0.120115            0.000000              0.355492
# 16              0.136476            0.082835              0.474837
# 17              0.117879            0.000000              0.381909
# 18              0.121921            0.082835              0.454163
# 19              0.121532            0.082835              0.448340
# 20              0.117155            0.082835              0.471790
# 21              0.115516            0.082835              0.472633
# 22              0.088086            0.000000              0.371278
# 23              0.122795            0.082835              0.470981
# 24              0.144744            0.082835              0.480803
# 25              0.131807            0.082835              0.507624
# 26              0.107482            0.082835              0.435563
# 27              0.099248            0.000000              0.322910
# 28              0.122605            0.082835              0.471448
# 29              0.109827            0.082835              0.476565
# 30              0.133748            0.082835              0.475488
# 31              0.121600            0.082835              0.453645
# 32              0.147452            0.082835              0.489922
# 33              0.122918            0.000000              0.371282
# 34              0.111785            0.082835              0.465348
# 35              0.141710            0.082835              0.464267
# 36              0.121193            0.082835              0.472030
# 37              0.128448            0.082835              0.487920
# 38              0.121233            0.082835              0.486086
# 39              0.146698            0.000000              0.421176
# 40              0.106297            0.000000              0.391661

# %% [markdown]
# Observations:
# <ul>
# <li>We observe that countries with higher scores in economic status, such as Luxembourg, Switzerland, and Ireland, tend to have higher health quality indices.</li>
# <li>Countries with lower mortality rates, such as Sweden and Denmark, tend to have higher health quality indices.</li>
# <li>Countries with lower disease burdens, such as Iceland and Finland, tend to have higher health quality indices.</li>
# <li>Developed countries tend to have marginally higher health quality index scores compared to developing countries.</li>
# </ul>

# %% [markdown]
# Based on the calculated health quality index
# The top 5 countries with the best health quality are:
#
# <ul>
# <li>Luxembourg</li>
# <li>Switzerland</li>
# <li>Ireland</li>
# <li>Netherlands</li>
# <li>Sweden</li>
#
# The bottom 5 countries with the worst health quality are:
#
# </ul>
# <ul>
# <li>Georgia</li>
# <li>Ukraine</li>
# <li>Bosnia and Herzegovina</li>
# <li>Turkey</li>
# <li>Azerbaijan</li>
# </ul>

# %%
import matplotlib.pyplot as plt

# Filter data for best and worst countries
best_countries = sub_indicators[sub_indicators['Health_quality_index'] == sub_indicators['Health_quality_index'].max()]
worst_countries = sub_indicators[sub_indicators['Health_quality_index'] == sub_indicators['Health_quality_index'].min()]

# Extract country names
best_country = best_countries['Country'].values[0]
worst_country = worst_countries['Country'].values[0]

# Select data for best and worst countries
best_data = sub_indicators.loc[sub_indicators['Country'] == best_country].drop(columns=['Country', 'Health_quality_index']).squeeze()
worst_data = sub_indicators.loc[sub_indicators['Country'] == worst_country].drop(columns=['Country', 'Health_quality_index']).squeeze()

# Plotting
plt.figure(figsize=(10, 6))
best_data.plot(label=best_country)
worst_data.plot(label=worst_country)

# Add labels and title
plt.title('Sub-Indicators for Best and Worst Countries')
plt.xlabel('Sub-Indicator')
plt.ylabel('Value')
plt.legend()

# Show plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for Luxembourg
luxembourg_data = sub_indicators[sub_indicators['Country'] == 'Luxembourg'].iloc[:, 1:].squeeze()
def get_best_country(df):
    return df[df['Health_quality_index'] == df['Health_quality_index'].max()].iloc[:, 1:].squeeze()

def get_average_country(df):
    return df.mean()

# %%
import numpy as np
import matplotlib.pyplot as plt

categories = list(luxembourg_data.index[:-2])  # Exclude 'Development_Status' and 'Health_quality_index'
values = luxembourg_data.values[:-2]  # Exclude the corresponding value

# Define best and average values for each sub-indicator
best_values = sub_indicators.iloc[:, 1:-2].max()
avg_values = sub_indicators.iloc[:, 1:-2].mean()
max_value = sub_indicators.iloc[:, 1:-2].max().max()
values_scaled = values / max_value
best_values_scaled = best_values / max_value
avg_values_scaled = avg_values / max_value

# Calculate angles for radar chart
num_vars = len(categories)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values_scaled = np.concatenate((values_scaled,[values_scaled[0]]))
best_values_scaled = np.concatenate((best_values_scaled,[best_values_scaled[0]]))
avg_values_scaled = np.concatenate((avg_values_scaled,[avg_values_scaled[0]]))
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
ax.fill(angles, values_scaled, color='green', alpha=0.25)
ax.plot(angles, values_scaled, color='green', linewidth=2, linestyle='solid', label='Luxembourg')
ax.plot(angles, best_values_scaled, color='blue', linewidth=1, linestyle='dotted', label='Best')
ax.plot(angles, avg_values_scaled, color='red', linewidth=1, linestyle='dotted', label='Average')
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

plt.title('Spider Web Plot for Luxembourg with Best and Average Values', size=20)
plt.legend()
plt.show()

# %% [markdown]
# explanation

# %%
# In detail for each variable

import numpy as np
import matplotlib.pyplot as plt

# Selecting data for Luxembourg and exclude 'Country_Status', 'Year', and 'Health_quality_index'
luxembourg_data = df[df['Country'] == 'Luxembourg'].iloc[:, 1:-2]

categories = list(luxembourg_data.columns)
values = luxembourg_data.values[0]

# Define best and average values for each sub-indicator
best_values = df.iloc[:, 1:-2].max()
avg_values = df.iloc[:, 1:-2].mean()

max_value = df.iloc[:, 1:-2].max().max()
values_scaled = values / max_value
best_values_scaled = best_values / max_value
avg_values_scaled = avg_values / max_value

# Calculate angles for radar chart
num_vars = len(categories)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values_scaled = np.concatenate((values_scaled,[values_scaled[0]]))
best_values_scaled = np.concatenate((best_values_scaled,[best_values_scaled[0]]))
avg_values_scaled = np.concatenate((avg_values_scaled,[avg_values_scaled[0]]))
angles += angles[:1]

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
ax.fill(angles, values_scaled, color='green', alpha=0.25)
ax.plot(angles, values_scaled, color='green', linewidth=2, linestyle='solid', label='Luxembourg')
ax.plot(angles, best_values_scaled, color='blue', linewidth=1, linestyle='dotted', label='Best')
ax.plot(angles, avg_values_scaled, color='red', linewidth=1, linestyle='dotted', label='Average')
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

plt.title('Spider Web Plot for Luxembourg with Best and Average Values', size=20)
plt.legend()
plt.show()

# %%
# RADAR PLOT for worst health quality country

import numpy as np
import matplotlib.pyplot as plt

azerbaijan_data = sub_indicators[sub_indicators['Country'] == 'Azerbaijan'].iloc[:, 1:].squeeze()
def get_best_country(df):
    return df[df['Health_quality_index'] == df['Health_quality_index'].max()].iloc[:, 1:].squeeze()

def get_average_country(df):
    return df.mean()

# Define categories and values for Luxembourg
categories = list(azerbaijan_data.index[:-2])  # Exclude 'Development_Status' and 'Health_quality_index'
values = azerbaijan_data.values[:-2]  # Exclude the corresponding value

# Define best and average values for each sub-indicator
best_values = sub_indicators.iloc[:, 1:-2].max()
avg_values = sub_indicators.iloc[:, 1:-2].mean()

# Adjust values for plotting
max_value = sub_indicators.iloc[:, 1:-2].max().max()
values_scaled = values / max_value
best_values_scaled = best_values / max_value
avg_values_scaled = avg_values / max_value

# Calculate angles for radar chart
num_vars = len(categories)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The plot is a circle, so we need to "complete the loop" and append the start to the end.
values_scaled = np.concatenate((values_scaled,[values_scaled[0]]))
best_values_scaled = np.concatenate((best_values_scaled,[best_values_scaled[0]]))
avg_values_scaled = np.concatenate((avg_values_scaled,[avg_values_scaled[0]]))
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
ax.fill(angles, values_scaled, color='green', alpha=0.25)
ax.plot(angles, values_scaled, color='green', linewidth=2, linestyle='solid', label='Luxembourg')
ax.plot(angles, best_values_scaled, color='blue', linewidth=1, linestyle='dotted', label='Best')
ax.plot(angles, avg_values_scaled, color='red', linewidth=1, linestyle='dotted', label='Average')
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

plt.title('Spider Web Plot for Azerbaijan with Best and Average Values', size=20)
plt.legend()
plt.show()
